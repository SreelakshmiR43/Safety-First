# %% [markdown]
# <a href="https://colab.research.google.com/github/SreelakshmiR43/Safety-First/blob/main/crimemap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
import warnings 
warnings.filterwarnings("ignore")

# %%
import pandas as pd

data = pd.read_excel("/content/crime.xlsx")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Crime Type        33 non-null     object
#  1   Location          33 non-null     object
#  2   Number of Crimes  33 non-null     int64
#  3   Latitude          33 non-null     float64
#  4   Longitude         33 non-null     float64
#  5   Date              33 non-null     datetime64[ns]
#  6   Time              33 non-null     object
#  7   Location Type     33 non-null     object
#  8   Severity          33 non-null     object
#  9   Description       33 non-null     object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(6)
# memory usage: 2.7+ KB

# %%
data_samples = data.sample(n=20,random_state = 42)

# %%
data_samples.index = np.arange(0,len(data_samples))

# %%
data_samples.isna().sum()
# Out:
# Crime Type          0
# Location            0
# Number of Crimes    0
# Latitude            0
# Longitude           0
# Date                0
# Time                0
# Location Type       0
# Severity            0
# Description         0
# dtype: int64

# %%
data_samples.dropna(axis=0,inplace=True)

# %%
data_samples.drop(["Crime Type","Location","Date","Time","Location Type","Severity","Description"],axis=1,inplace=True)

# %%
data_samples.head()
# Out:
#    Number of Crimes  Latitude  Longitude
# 0                 1  9.595420  76.780844
# 1                21  9.600600  76.771900
# 2                 1  9.606287  76.774626
# 3                 2  9.583800  76.779500
# 4                22  9.597600  76.539300

# %%
List = data_samples["Number of Crimes"].unique()

List2 = data_samples["Number of Crimes"]
Ratio = []

counted = Counter(List2) 
mostcommon = counted.most_common(10)
x,y = zip(*mostcommon)
x,y = list(x),list(y)
# %% 
plt.figure(figsize = (20,8))
ax = sns.barplot(x = x , y = y, palette = sns.cubehelix_palette(len(x)))
plt.xticks(rotation= 15)
plt.xlabel("Number of Crimes")
plt.ylabel("Crimes")
plt.title("Most common 10 crime places ")
plt.show()

# %%
PrimaryType = data_samples["Number of Crimes"]
PrimaryTypeCounted = Counter(PrimaryType)
MostCommonPT = PrimaryTypeCounted.most_common(10)
x,y = zip(*MostCommonPT)
x,y  = list(x),list(y)

# %% 

plt.figure(figsize=(15,8))
ax = sns.barplot(x=x, y=y,palette = "deep")
plt.xticks(rotation= 15)
plt.xlabel("Primary Type")
plt.ylabel("Crimes")
plt.show()

# %%
import folium

# Create a map centered on the mean latitude and longitude
map_center = [data_samples['Latitude'].mean(), data_samples['Longitude'].mean()]
m = folium.Map(location=map_center, zoom_start=12)

# Iterate over unique values of number of crimes
for num in List:
    # Subset the data to only include rows with this number of crimes
    subset = data_samples[data_samples['Number of Crimes'] == num]
    
    # Create a feature group for this subset
    fg = folium.FeatureGroup(name=str(num))
    
    # Add a marker for each row in the subset
    for i, row in subset.iterrows():
        popup_text = "Latitude: {}<br>Longitude: {}<br>Number of Crimes: {}".format(row['Latitude'], row['Longitude'], num)
        marker = folium.Marker(location=[row['Latitude'], row['Longitude']], popup=popup_text)
        marker.add_to(fg)
    
    # Add the feature group to the map
    fg.add_to(m)

# Add layer control to the map
folium.LayerControl().add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_95a72e9b33d08dcad49af48c6f2435af {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_95a72e9b33d08dcad49af48c6f2435af&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_95a72e9b33d08dcad49af48c6f2435af = L.map(
#                 &quot;map_95a72e9b33d08dcad49af48c6f2435af&quot;,
#                 {
#                     center: [9.59418925, 76.71499015],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e01850e067264e4d7ad72eb68a07f91a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_95a72e9b33d08dcad49af48c6f2435af);
#
#
#             var feature_group_9404d07c79cf9300fee1146d68191717 = L.featureGroup(
#                 {}
#             ).addTo(map_95a72e9b33d08dcad49af48c6f2435af);
#
#
#             var marker_3ce1cb4e7cd699b38116ffb52817baed = L.marker(
#                 [9.59542, 76.780844],
#                 {}
#             ).addTo(feature_group_9404d07c79cf9300fee1146d68191717);
#
#
#         var popup_2ebd32218fd2df20da4c694f4b6a3418 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b0fed989838fbbd1cba13ef6df36f701 = $(`&lt;div id=&quot;html_b0fed989838fbbd1cba13ef6df36f701&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 9.59542&lt;br&gt;Longitude: 76.780844&lt;br&gt;Number of Crimes: 1&lt;/div&gt;`)[0];
#             popup_2ebd32218fd2df20da4c694f4b6a3418.setContent(html_b0fed989838fbbd1cba13ef6df36f701);
#
#
#         marker_3ce1cb4e7cd699b38116ffb52817baed.bindPopup(popup_2ebd32218fd2df20da4c694f4b6a3418)
#         ;
#
#
#
#
#             var marker_c26e3968a92a13fd2adbef49c3934595 = L.marker(
#                 [9.606287, 76.774626],
#                 {}
#             ).addTo(feature_group_9404d07c79cf9300fee1146d68191717);
#
#
#         var popup_03ff5c735284784f7f252d69bbd1a5ba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0e705d7cdd41ee8404a9c595b7460d56 = $(`&lt;div id=&quot;html_0e705d7cdd41ee8404a9c595b7460d56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 9.606287&lt;br&gt;Longitude: 76.774626&lt;br&gt;Number of Crimes: 1&lt;/div&gt;`)[0];
#             popup_03ff5c735284784f7f252d69bbd1a5ba.setContent(html_0e705d7cdd41ee8404a9c595b7460d56);
#
#
#         marker_c26e3968a92a13fd2adbef49c3934595.bindPopup(popup_03ff5c735284784f7f252d69bbd1a5ba)
#         ;
#
#
#
#
#             var marker_1e0ecb2ef4672a80f37ce57a5fa51802 = L.marker(
#                 [9.586264, 76.778822],
#                 {}
#             ).addTo(feature_group_9404d07c79cf9300fee1146d68191717);
#
#
#         var popup_75e37d7a98dc10b65e012348d9b2b781 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_91339a80d06a76b946dc3c745d48c0aa = $(`&lt;div id=&quot;html_91339a80d06a76b946dc3c745d48c0aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 9.586264&lt;br&gt;Longitude: 76.778822&lt;br&gt;Number of Crimes: 1&lt;/div&gt;`)[0];
#             popup_75e37d7a98dc10b65e012348d9b2b781.setContent(html_91339a80d06a76b946dc3c745d48c0aa);
#
#
#         marker_1e0ecb2ef4672a80f37ce57a5fa51802.bindPopup(popup_75e37d7a98dc10b65e012348d9b2b781)
#         ;
#
#
#
#
#             var marker_f93da94dc6123bbeccbcc68042dbfa15 = L.marker(
#                 [9.587914, 76.778011],
#                 {}
#             ).addTo(feature_group_9404d07c79cf9300fee1146d68191717);
#
#
#         var popup_9c32c0d9dd17ced159a9fe83795eb125 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1a2035e3f816863589b11f694af7865d = $(`&lt;div id=&quot;html_1a2035e3f816863589b11f694af7865d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 9.587914&lt;br&gt;Longitude: 76.778011&lt;br&gt;Number of Crimes: 1&lt;/div&gt;`)[0];
#             popup_9c32c0d9dd17ced159a9fe83795eb125.setContent(html_1a2035e3f816863589b11f694af7865d);
#
#
#         marker_f93da94dc6123bbeccbcc68042dbfa15.bindPopup(popup_9c32c0d9dd17ced159a9fe83795eb125)
#         ;
#
#
#
#
#             var feature_group_650937f2a214287ebdad11ae1064d340 = L.featureGroup(
#                 {}
#             ).addTo(map_95a72e9b33d08dcad49af48c6f2435af);
#
#
#             var marker_da132f958207c9f708b27b1b7cb95d4f = L.marker(
#                 [9.6006, 76.7719],
#                 {}
#             ).addTo(feature_group_650937f2a214287ebdad11ae1064d340);
#
#
#         var popup_cbf193cfc477d40fb63ee1412d0e73cc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3eb75eb2c07c121d3fff42b52c589913 = $(`&lt;div id=&quot;html_3eb75eb2c07c121d3fff42b52c589913&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 9.6006&lt;br&gt;Longitude: 76.7719
